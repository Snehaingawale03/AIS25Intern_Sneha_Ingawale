# %%
# !pip install langchain langchain_community langchain_huggingface
# !pip install llama-index transformers sentence-transformers
# !pip install openai huggingface_hub streamlit python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 49.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.9 MB/s eta 0:00:00
# ...

# %%
import os

os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
from langchain.llms import HuggingFaceHub
from langchain import PromptTemplate, LLMChain

# %%
llm = HuggingFaceHub(
    repo_id="meta-llama/Llama-2-7b-chat-hf",  # Change this to the model you want
    model_kwargs={"temperature": 0.7, "max_length": 512}
)

prompt = PromptTemplate(template="What is LangChain?", input_variables=[])
llm_chain = LLMChain(llm=llm, prompt=prompt)

response = llm_chain.run({})
print(response)
# Out:
# <ipython-input-6-a16a602076a5>:1: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   llm = HuggingFaceHub(
# <ipython-input-6-a16a602076a5>:7: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain = LLMChain(llm=llm, prompt=prompt)
# <ipython-input-6-a16a602076a5>:9: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm_chain.run({})
# ...

# %%
# %%writefile streamlit_app.py
import streamlit as st
from langchain.llms import HuggingFaceHub

st.title("LangChain with Hugging Face LLMs")

llm = HuggingFaceHub(
    repo_id="meta-llama/Llama-2-7b-chat-hf",
    model_kwargs={"temperature": 0.7, "max_length": 512}
)

user_input = st.text_input("Ask a question:")

if user_input:
    response = llm(user_input)
    st.write(response)
# Out:
# Writing streamlit_app.py

# %%
# !wget -q -O - https://loca.lt/mytunnelpassword
# Out:
# 34.145.237.7

# %%
# !streamlit run streamlit_app.py & npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴
# ...
#
# ⠦⠧⠇⠏⠋
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.145.237.7:8501
#
# your url is: https://wild-readers-cheer.loca.lt
# /usr/local/lib/python3.11/dist-packages/langchain/llms/__init__.py:549: LangChainDeprecationWarning: Importing LLMs from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.llms import HuggingFaceHub`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/langchain/llms/__init__.py:549: LangChainDeprecationWarning: Importing LLMs from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# ...

# %%
pip install streamlit langchain langchain-community langchain-huggingface faiss-cpu chromadb pypdf

# %%
# %%writefile streamlit_app.py
import streamlit as st
import os
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFaceEndpoint

# ✅ Set Hugging Face API Token
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# ✅ Load LLM Model
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct",
    task="text-generation",  # ✅ Ensure correct task type
    temperature=0.7,
    max_new_tokens=100
)

# ✅ Streamlit UI
st.title("📄 RAG Chatbot with PDF & FAISS")

# ✅ File Upload
uploaded_file = st.file_uploader("Upload a PDF", type=["pdf"])

if uploaded_file:
    # ✅ Save uploaded PDF
    file_path = f"./{uploaded_file.name}"
    with open(file_path, "wb") as f:
        f.write(uploaded_file.getbuffer())

    # ✅ Load PDF Content
    loader = PyPDFLoader(file_path)
    documents = loader.load()

    # ✅ Split Text into Chunks
    text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=100)
    docs = text_splitter.split_documents(documents)

    # ✅ Create FAISS Vector Store
    embeddings = HuggingFaceEmbeddings()
    vector_store = FAISS.from_documents(docs, embeddings)
    retriever = vector_store.as_retriever()

    st.success("✅ PDF processed and indexed!")

    # ✅ User Query
    user_query = st.text_input("Ask something about the document:")

    if st.button("Generate Response"):
        if user_query:
            # ✅ Retrieval-Augmented Generation (RAG)
            qa_chain = RetrievalQA.from_chain_type(llm, retriever=retriever)
            response = qa_chain.run(user_query)


            # ✅ Display Final Response
            st.write("### 🤖 AI Response:")
            st.write(response)
# Out:
# Overwriting streamlit_app.py

# %%
# !streamlit run streamlit_app.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙⠹
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.145.237.7:8501
#
# ⠸⠼⠴your url is: https://long-jars-jog.loca.lt
# /content/streamlit_app.py:3: LangChainDeprecationWarning: Importing FAISS from langchain.vectorstores is deprecated. Please replace deprecated imports:
#
# >> from langchain.vectorstores import FAISS
#
# with new imports of:
#
# >> from langchain_community.vectorstores import FAISS
# You can use the langchain cli to **automatically** upgrade many imports. Please see documentation here <https://python.langchain.com/docs/versions/v0_2/>
#   from langchain.vectorstores import FAISS
# /content/streamlit_app.py:4: LangChainDeprecationWarning: Importing HuggingFaceEmbeddings from langchain.embeddings is deprecated. Please replace deprecated imports:
#
# >> from langchain.embeddings import HuggingFaceEmbeddings
#
# with new imports of:
#
# ...
